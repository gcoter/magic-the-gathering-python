# %%
import sys
sys.path.append("../")

import pandas as pd
from magic_the_gathering.cards.deck_creator import RandomVanillaDeckCreator

# %%
legal_lands_df = pd.read_csv("../data/basic_land_cards.csv")

# %%
legal_lands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901 entries, 0 to 3900
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3901 non-null   object
#  1   name            3901 non-null   object
#  2   set             3901 non-null   object
#  3   set_name        3901 non-null   object
#  4   rarity          3901 non-null   object
#  5   type_line       3901 non-null   object
#  6   colors          3901 non-null   object
#  7   color_identity  3901 non-null   object
#  8   mana_cost       0 non-null      float64
#  9   power           0 non-null      float64
#  10  toughness       0 non-null      float64
#  11  oracle_text     3901 non-null   object
#  12  keywords        3901 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 396.3+ KB

# %%
legal_creatures_df = pd.read_csv("../data/vanilla_creature_cards.csv")

# %%
legal_creatures_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1050 non-null   object
#  1   name            1050 non-null   object
#  2   set             1050 non-null   object
#  3   set_name        1050 non-null   object
#  4   rarity          1050 non-null   object
#  5   type_line       1050 non-null   object
#  6   colors          1050 non-null   object
#  7   color_identity  1050 non-null   object
#  8   mana_cost       1050 non-null   object
#  9   power           1050 non-null   float64
#  10  toughness       1050 non-null   float64
#  11  oracle_text     0 non-null      float64
#  12  keywords        1050 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 106.8+ KB

# %%
deck_creator = RandomVanillaDeckCreator(
    legal_lands_df,
    legal_creatures_df,
    deck_size=60,
    lands_proportion=0.4,
)

# %%
deck_creator.create_decks(n_players=2)
# Out:
# [OrderedDict([('140943d6-f8e0-4c9a-b94b-7594c4b06418',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('2e07681c-2d4b-410e-a4da-f0b1e2c29f47',
#                Card(name=Flameborn Viron, color_identity=['R'], type=Creature — Phyrexian Insect, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 4}, state=None)),
#               ('f2da5d57-aa9e-4277-b5f3-e30a0bc0207d',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('84a66dfb-5424-4041-91b2-fa0bc776eec6',
#                Card(name=Barktooth Warbeard, color_identity=['B', 'R'], type=Legendary Creature — Human Warrior, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 2, 'G': 0, 'any': 4}, state=None)),
#               ('e1a1db65-27d9-4c93-b724-83801d5cb0d3',
#                Card(name=Feral Maaka, color_identity=['R'], type=Creature — Cat, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('e1d448fe-0585-4475-aaf9-7ecf39476141',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('db5197d5-3fda-472d-ac09-bec421bfbdd0',
#                Card(name=Scarwood Goblins, color_identity=['G', 'R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 1, 'any': 0}, state=None)),
#               ('1de52617-d78c-4da5-9687-0198a6bf4782',
#                Card(name=Falkenrath Reaver, color_identity=['R'], type=Creature — Vampire, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('2453d98e-1f74-4ffe-ada1-d41dc8b3c565',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('f1b3dae2-2117-4c57-8094-9d6b10b814de',
#                Card(name=Hurloon Minotaur, color_identity=['R'], type=Creature — Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 1}, state=None)),
#               ('1311d43a-5e7f-4b47-9aed-244890c00376',
#                Card(name=Crookshank Kobolds, color_identity=['R'], type=Creature — Kobold, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('5358c3ea-4905-4e48-bcbc-d682f30b9cd9',
#                Card(name=Balduvian Barbarians, color_identity=['R'], type=Creature — Human Barbarian, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 1}, state=None)),
#               ('1d11793e-1f9c-4d8e-8d49-2e0dfca3c324',
#                Card(name=Axegrinder Giant, color_identity=['R'], type=Creature — Giant Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 4}, state=None)),
#               ('3fd6613f-ca2c-454e-8543-1007999a339d',
#                Card(name=Barktooth Warbeard, color_identity=['B', 'R'], type=Legendary Creature — Human Warrior, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 2, 'G': 0, 'any': 4}, state=None)),
#               ('ccb4fe6d-e2cf-41c4-8d34-251c334909d6',
#                Card(name=Gray Ogre, color_identity=['R'], type=Creature — Ogre, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('d4f8f2d4-434b-49aa-a122-076134fdec40',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('6928477e-70b8-4ea0-85f1-99671e45f478',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('a600bf77-3a72-4d75-9b8c-66bcf8629fcb',
#                Card(name=Fearless Halberdier, color_identity=['R'], type=Creature — Human Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('ed154e41-a0d6-420b-95d8-8edc76749d68',
#                Card(name=Kobolds of Kher Keep, color_identity=['R'], type=Creature — Kobold, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('56ee8557-496e-4e9f-90c1-7d70e6316ad5',
#                Card(name=Fusion Elemental, color_identity=['B', 'G', 'R', 'U', 'W'], type=Creature — Elemental, mana_cost={'W': 1, 'U': 1, 'B': 1, 'R': 1, 'G': 1, 'any': 0}, state=None)),
#               ('6a83b97c-5080-4a88-916f-68aabcd19d2c',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('c1f79bac-92ac-4503-8453-93d63000923a',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('39e86ed8-7272-43cb-842d-e68ce9f119a9',
#                Card(name=Mons's Goblin Raiders, color_identity=['R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 0}, state=None)),
#               ('b01b3c31-2ce0-4838-9dfa-1689a4fd5d0e',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('1ccf2ae2-7fd7-477d-8fb1-255d380f3411',
#                Card(name=Lowland Giant, color_identity=['R'], type=Creature — Giant, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 2}, state=None)),
#               ('15429543-eb08-4422-beda-66ef99deec68',
#                Card(name=Mons's Goblin Raiders, color_identity=['R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 0}, state=None)),
#               ('2d935baf-d35c-4991-ae60-25abbcc443d8',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('cc848eff-230b-42fa-8edb-120e1c77315e',
#                Card(name=Orazca Raptor, color_identity=['R'], type=Creature — Dinosaur, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 2}, state=None)),
#               ('d9b4a415-e20e-4823-b6f7-38447626537f',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('e4648cdf-9bba-4ed0-9a39-2fa53e310388',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('9cc2ace8-89cb-4335-80fb-fa3678913d99',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('89e13e68-7a24-47df-b21b-b1d420f5d109',
#                Card(name=Hyena Pack, color_identity=['R'], type=Creature — Hyena, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 2}, state=None)),
#               ('a657a3a6-40a5-48b0-bedd-8a4d5df4653b',
#                Card(name=Feral Maaka, color_identity=['R'], type=Creature — Cat, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('8ea45410-b6b7-4d73-b15c-f068b3f140c7',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('92e77c1e-9755-48a1-b402-0f79930256d7',
#                Card(name=Axegrinder Giant, color_identity=['R'], type=Creature — Giant Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 4}, state=None)),
#               ('836a4e1c-b5fc-482c-8b7e-4aab88dbb1fe',
#                Card(name=Lagac Lizard, color_identity=['R'], type=Creature — Lizard, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('dacab37b-a961-4de8-b25e-5cb968182a22',
#                Card(name=Leopard-Spotted Jiao, color_identity=['R'], type=Creature — Beast, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('c640f532-6f60-4f81-8482-43c857216d06',
#                Card(name=Goblin Bruiser, color_identity=['R'], type=Creature — Goblin Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 1}, state=None)),
#               ('2bad74e3-d62e-41bc-8e66-0b26807687a4',
#                Card(name=Streetbreaker Wurm, color_identity=['G', 'R'], type=Creature — Wurm, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 1, 'any': 3}, state=None)),
#               ('d442e0f5-f7ef-4d5c-8df1-a920bb1daa9b',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('09e22b25-ddd6-48b6-b8fa-d80fff146ef9',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('f9ee10f1-d903-4098-9937-337a0662950a',
#                Card(name=Goblin Bruiser, color_identity=['R'], type=Creature — Goblin Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 1}, state=None)),
#               ('07b1bca3-cdd3-4408-851f-8e8fba7aa6fc',
#                Card(name=Summit Prowler, color_identity=['R'], type=Creature — Yeti, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 2}, state=None)),
#               ('3583910d-5a26-4d82-9c4a-00483749c7cc',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('25c1d09b-6716-493e-83e2-dceb5f4f515a',
#                Card(name=Goblin Bruiser, color_identity=['R'], type=Creature — Goblin Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 1}, state=None)),
#               ('d5f944ef-d119-4df7-848f-72a00aa985a8',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('0cb5d77f-1fcc-414e-9e39-c03efb9a9ff3',
#                Card(name=Jerrard of the Closed Fist, color_identity=['G', 'R'], type=Legendary Creature — Human Knight, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 2, 'any': 3}, state=None)),
#               ('0982bc24-ee77-4b06-a26a-592af03ec1f2',
#                Card(name=Gore Swine, color_identity=['R'], type=Creature — Boar, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('3fed30bc-ee6e-4514-8860-aa9497894ca0',
#                Card(name=Frost Ogre, color_identity=['R'], type=Creature — Ogre Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 3}, state=None)),
#               ('8118c8ee-d911-4d1b-8145-6a6b2cb271d2',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('ac4b9bb6-da9c-41f2-8805-bc77e731ae43',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('e5a84395-bd92-4c1d-ad32-1d32047c89be',
#                Card(name=Loamdragger Giant, color_identity=['G', 'R'], type=Creature — Giant Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('cbd5b684-6d88-47cd-9296-5aa5bf9324c4',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('a07affcc-393b-4e40-a055-0495ba9929fa',
#                Card(name=Obsidian Giant, color_identity=['R'], type=Creature — Giant, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 4}, state=None)),
#               ('0ddc8b61-28df-4169-bf6d-6b96188e0abd',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('854be69b-f523-4930-968b-f227f2c25265',
#                Card(name=Fire Elemental, color_identity=['R'], type=Creature — Elemental, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 3}, state=None)),
#               ('248cbd8e-384e-404a-ad67-104889f55f0f',
#                Card(name=Gray Ogre, color_identity=['R'], type=Creature — Ogre, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('05d58787-526e-441d-9393-e58d4b5b1895',
#                Card(name=Lady Orca, color_identity=['B', 'R'], type=Legendary Creature — Demon, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 1, 'G': 0, 'any': 5}, state=None)),
#               ('24cd67d9-4786-4319-81f4-1486a3906c81',
#                Card(name=Lagac Lizard, color_identity=['R'], type=Creature — Lizard, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('2498df98-44e5-4ad4-8064-4e0996ec772f',
#                Card(name=Kobolds of Kher Keep, color_identity=['R'], type=Creature — Kobold, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None))]),
#  OrderedDict([('be5a1401-8f11-41ef-a400-13188c302db9',
#                Card(name=Watchwolf, color_identity=['G', 'W'], type=Creature — Wolf, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 1, 'any': 0}, state=None)),
#               ('0284d14f-9336-4595-b58d-013d06678b77',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('5791c266-57c3-40d8-afda-2c100426838e',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('3eb1931a-9b31-4193-81bd-2f50089469ac',
#                Card(name=Little Girl, color_identity=['W'], type=Creature — Human Child, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('0036d57c-5285-4c01-b122-46ed8eeab90c',
#                Card(name=Knight of the Keep, color_identity=['W'], type=Creature — Human Knight, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('5cdf8299-4b9c-4adc-baec-62526803ef82',
#                Card(name=Staunch Shieldmate, color_identity=['W'], type=Creature — Dwarf Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('1cb4a66c-6dd6-47f7-aa65-430475278bb3',
#                Card(name=Ageless Guardian, color_identity=['W'], type=Creature — Spirit Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('7549badf-02ed-4ba8-ab37-bff2176f3911',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('99fe5838-b299-4945-8dfb-58819ab36981',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('2fa6d617-e093-46a1-9ff3-944d75d8e0a3',
#                Card(name=Thraben Purebloods, color_identity=['W'], type=Creature — Dog, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('99cb6842-e7e9-42f3-82cd-18fa0c47723a',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('f4022480-ff20-47a2-a79c-8a528c1a985e',
#                Card(name=Woolly Thoctar, color_identity=['G', 'R', 'W'], type=Creature — Beast, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 1, 'G': 1, 'any': 0}, state=None)),
#               ('dd153a50-a58b-4e5c-9685-083eabbe2197',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('52a4de7b-819c-4bc6-a9c7-8a73406274ef',
#                Card(name=Savannah Lions, color_identity=['W'], type=Creature — Cat, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('1f7d9abe-be9e-4698-bd0e-c2e7b315d790',
#                Card(name=Blade of the Sixth Pride, color_identity=['W'], type=Creature — Cat Rebel, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('81e8e115-63e8-47ce-8194-b7179e37f63e',
#                Card(name=Ageless Guardian, color_identity=['W'], type=Creature — Spirit Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('da847f09-66ea-4eb1-9e7b-1953ee7173f9',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('5744efdf-ec80-4092-b35e-8f9ec40e3169',
#                Card(name=Valiant Guard, color_identity=['W'], type=Creature — Human Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('4befd566-88aa-4473-856c-103ef86d23c5',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('53f0a9e8-39c5-4c4e-b048-a8330eac03c6',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('16c4aec6-9e1f-4640-97b4-c80f14ebe686',
#                Card(name=Thraben Purebloods, color_identity=['W'], type=Creature — Dog, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('a23b38e7-f03d-4e31-8ccd-9bdb4c03c35e',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('fac756be-4c90-45b1-a1ae-d68cf541a98f',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('b7398737-6458-464a-9671-8cff79d721f5',
#                Card(name=Traveling Philosopher, color_identity=['W'], type=Creature — Human Advisor, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('69514c90-97d3-4d1c-ae41-5b517836154e',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('fdbcf73c-a1c1-4fc5-b109-757fd00da678',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('9d093b7d-0805-49cf-8033-02642b79be67',
#                Card(name=Blade of the Sixth Pride, color_identity=['W'], type=Creature — Cat Rebel, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('2226ac98-feac-411e-b315-7d9db3751a64',
#                Card(name=Loxodon Line Breaker, color_identity=['W'], type=Creature — Elephant Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('3f770575-a75c-46ec-a58d-23c0e1bd909b',
#                Card(name=Tobias Andrion, color_identity=['U', 'W'], type=Legendary Creature — Human Advisor, mana_cost={'W': 1, 'U': 1, 'B': 0, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('70a06acc-ed7d-4abb-9dcc-bed359595915',
#                Card(name=Knight of the Keep, color_identity=['W'], type=Creature — Human Knight, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('b60099f3-a100-4573-abef-4e604750cdc3',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('5ab6f6c9-53c4-45da-8480-ca2544f9d3a4',
#                Card(name=Those Who Serve, color_identity=['W'], type=Creature — Zombie, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('b570a685-df37-4c27-82b8-318e8e265013',
#                Card(name=Blade of the Sixth Pride, color_identity=['W'], type=Creature — Cat Rebel, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('64aa9378-8140-4411-9dfc-cf0b1079e66c',
#                Card(name=Alaborn Trooper, color_identity=['W'], type=Creature — Human Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('8135ab4c-78e7-44d5-8483-90dc886648be',
#                Card(name=Oreskos Swiftclaw, color_identity=['W'], type=Creature — Cat Warrior, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('16f44743-10ae-4362-a5b4-b42870e33080',
#                Card(name=Silvercoat Lion, color_identity=['W'], type=Creature — Cat, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('ab1cc563-2211-4ccd-83a1-b9dc44795b5a',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('415727b0-b20d-4d1e-91ec-5aa6cb6a7d24',
#                Card(name=Devoted Hero, color_identity=['W'], type=Creature — Elf Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('03f32198-0350-44a7-ae59-7c98b028f423',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('18525875-3482-4761-8ac5-e4f0721f6037',
#                Card(name=Shrine Keeper, color_identity=['W'], type=Creature — Human Cleric, mana_cost={'W': 2, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('539c93d5-05e0-4a9a-bbcb-d713e69e6b9d',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('89c1ca8a-c79a-4eb9-bc6a-bf42254d8571',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('53041080-52b5-4c12-ad1a-be16205eb683',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('07b0d6d7-9ee8-4839-a04e-a6d03237e858',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('738b7367-a7b3-45f2-b1fe-48220ac23bdc',
#                Card(name=Armored Warhorse, color_identity=['W'], type=Creature — Horse, mana_cost={'W': 2, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('f41e0b71-c488-4d0f-ac81-caa16258b803',
#                Card(name=Those Who Serve, color_identity=['W'], type=Creature — Zombie, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('a5f0a155-cd9c-44a9-b741-d804966ba0c4',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('da2f7c0d-48e0-499d-9bac-d07ed0789fe0',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('bcd66ea7-4890-41bc-a87e-a283b3741593',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('1f96a277-b5ca-4bba-8146-d70606e31757',
#                Card(name=Ageless Guardian, color_identity=['W'], type=Creature — Spirit Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('29439863-fd09-4141-83d1-84ef9698ac20',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('c5677260-b4d6-471c-aecf-ea4f37a0655d',
#                Card(name=Jasmine Boreal, color_identity=['G', 'W'], type=Legendary Creature — Human, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 1, 'any': 3}, state=None)),
#               ('7e3c3be0-584b-46b5-b1f3-d5cd559b1282',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('2bb769da-1dad-46eb-938d-880ad786ad65',
#                Card(name=Staunch Shieldmate, color_identity=['W'], type=Creature — Dwarf Soldier, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('5834d7ef-e08b-45ed-997e-b4e321d1bd07',
#                Card(name=Traveling Philosopher, color_identity=['W'], type=Creature — Human Advisor, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('8aef27f4-ecf8-4ab4-9763-45077878bc1d',
#                Card(name=Keepers of the Faith, color_identity=['W'], type=Creature — Human Cleric, mana_cost={'W': 2, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('7d75d60f-dabf-437c-aef6-9d052d653d24',
#                Card(name=Raptor Companion, color_identity=['W'], type=Creature — Dinosaur, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('8674470e-7010-4260-8f34-2b584edc0c20',
#                Card(name=Woolly Thoctar, color_identity=['G', 'R', 'W'], type=Creature — Beast, mana_cost={'W': 1, 'U': 0, 'B': 0, 'R': 1, 'G': 1, 'any': 0}, state=None)),
#               ('5bd0201b-3bac-4dc8-92d9-9153b4109be3',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None)),
#               ('ef679a0c-4353-493b-be86-0ec2fa4be1da',
#                Card(name=Plains, color_identity=['W'], type=Basic Land — Plains, mana_cost=None, state=None))])]
