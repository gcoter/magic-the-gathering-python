# %%
import sys
sys.path.append("../")

import pandas as pd
from magic_the_gathering.cards.deck_creator import RandomVanillaDeckCreator

# %%
legal_lands_df = pd.read_csv("../data/basic_land_cards.csv")

# %%
legal_lands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901 entries, 0 to 3900
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3901 non-null   object
#  1   name            3901 non-null   object
#  2   set             3901 non-null   object
#  3   set_name        3901 non-null   object
#  4   rarity          3901 non-null   object
#  5   type_line       3901 non-null   object
#  6   colors          3901 non-null   object
#  7   color_identity  3901 non-null   object
#  8   mana_cost       0 non-null      float64
#  9   power           0 non-null      float64
#  10  toughness       0 non-null      float64
#  11  oracle_text     3901 non-null   object
#  12  keywords        3901 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 396.3+ KB

# %%
legal_creatures_df = pd.read_csv("../data/vanilla_creature_cards.csv")

# %%
legal_creatures_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1050 non-null   object
#  1   name            1050 non-null   object
#  2   set             1050 non-null   object
#  3   set_name        1050 non-null   object
#  4   rarity          1050 non-null   object
#  5   type_line       1050 non-null   object
#  6   colors          1050 non-null   object
#  7   color_identity  1050 non-null   object
#  8   mana_cost       1050 non-null   object
#  9   power           1050 non-null   float64
#  10  toughness       1050 non-null   float64
#  11  oracle_text     0 non-null      float64
#  12  keywords        1050 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 106.8+ KB

# %%
deck_creator = RandomVanillaDeckCreator(
    legal_lands_df,
    legal_creatures_df,
    deck_size=60,
    lands_proportion=0.4,
)

# %%
deck_creator.create_decks(n_players=2)
# Out:
# [OrderedDict([('097d85ed-a4b8-4024-a0ed-13b9b6dc350b',
#                Card(name=Catacomb Crocodile, color_identity=['B'], type=Creature — Crocodile, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('0f27ae52-732c-4b45-befc-f4a003b889f2',
#                Card(name=Nyxborn Marauder, color_identity=['B'], type=Enchantment Creature — Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 2, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('10d5f56c-4045-4c73-bbe1-d6f4c0534eae',
#                Card(name=Witch's Familiar, color_identity=['B'], type=Creature — Frog, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('efd4bb2e-3f2d-4970-a33f-87d0d8806055',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('5d750560-bd6c-4ab1-adcd-b52200713e3f',
#                Card(name=Catacomb Crocodile, color_identity=['B'], type=Creature — Crocodile, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('ddce240f-e150-4b5f-894a-bf5eab7d3179',
#                Card(name=Gloom Pangolin, color_identity=['B'], type=Creature — Nightmare Pangolin, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('c81515d1-7813-44f0-82ff-35064cf37f08',
#                Card(name=Wandering Tombshell, color_identity=['B'], type=Creature — Zombie Turtle, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('3f89303a-e8f0-4ce5-811d-909f8b9841c5',
#                Card(name=Wandering Tombshell, color_identity=['B'], type=Creature — Zombie Turtle, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('59287cd5-1149-4f56-a83e-51d6ad9c851a',
#                Card(name=Skeletal Snake, color_identity=['B'], type=Creature — Snake Skeleton, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('6ef0d1d8-5618-416d-8f74-6a26a25d2358',
#                Card(name=Catacomb Slug, color_identity=['B'], type=Creature — Slug, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('e59d53a9-6c26-4f92-b0ae-b1384176da3f',
#                Card(name=Vampire Noble, color_identity=['B'], type=Creature — Vampire Noble, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('cc8a88f9-897c-45c8-a831-016666547015',
#                Card(name=Dreg Reaver, color_identity=['B'], type=Creature — Zombie Beast, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('ccd0e610-beab-4a70-bb9f-80b97e47f752',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('1c837cc5-db45-403e-b3af-10fd9e19fbfe',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('9c5cf998-3ca3-4132-9342-6c3978b1d84b',
#                Card(name=Dross Crocodile, color_identity=['B'], type=Creature — Zombie Crocodile, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('dfc97169-cd49-4e70-b130-57e18a5d2789',
#                Card(name=Bane Alley Blackguard, color_identity=['B'], type=Creature — Human Rogue, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('cfbfd03f-61b2-4424-a400-5328f21fb769',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('2b2b1adc-eaec-4b4c-8640-0330a4617893',
#                Card(name=Moriok Reaver, color_identity=['B'], type=Creature — Human Warrior, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('3fd67428-6a63-4c46-8089-de4bd87b0e10',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('7a72c293-c65c-4bb5-a4c7-1dcf153e42f9',
#                Card(name=Rotting Mastodon, color_identity=['B'], type=Creature — Zombie Elephant, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('633af37e-8024-48d1-a2f7-bd5b3243e1ee',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('892376a5-82ea-4b51-89d6-001a7ef120c7',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('19b7083c-0597-4104-95af-8623d96bbe1f',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('e9df77fb-b2d4-48cc-a6e3-d439a577c9c3',
#                Card(name=Dakmor Scorpion, color_identity=['B'], type=Creature — Scorpion, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('c8725449-4af4-45fa-8121-83f15876e522',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('378ed11e-281f-4716-892f-5acfa4f85871',
#                Card(name=Skeletal Crocodile, color_identity=['B'], type=Creature — Crocodile Skeleton, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('3e251e53-923b-4d28-92f0-03f56524c1ca',
#                Card(name=Rotted Hulk, color_identity=['B'], type=Creature — Elemental, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('65e65947-4fe0-435c-aeb7-76bde2707f61',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('555a3665-8446-47ef-a746-3e5e5a9e9e2f',
#                Card(name=Undead Minotaur, color_identity=['B'], type=Creature — Zombie Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('1c53caed-865c-4319-be7b-2496533e000f',
#                Card(name=Catacomb Slug, color_identity=['B'], type=Creature — Slug, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('08e7bbaa-9573-4038-b87d-2b6ab152cd88',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('7ede274a-8b4b-404b-bdc0-526496e735e3',
#                Card(name=Mass of Ghouls, color_identity=['B'], type=Creature — Zombie Warrior, mana_cost={'W': 0, 'U': 0, 'B': 2, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('3842c2fd-afce-449b-81a4-f22bfe960b61',
#                Card(name=Yargle, Glutton of Urborg, color_identity=['B'], type=Legendary Creature — Frog Spirit, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 4}, state=None)),
#               ('d8888138-8dbc-44de-83b7-2c4ecaa90de1',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('991d0084-f3b5-4284-a945-cf6841bea4c0',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('134cd8d4-7efb-403f-8bd6-3d7a1be31591',
#                Card(name=Wei Infantry, color_identity=['B'], type=Creature — Human Soldier, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('f1134a37-a39c-447a-b96d-cc5a7495fdc8',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('b8b441d4-02ba-4235-80be-b525b8ae1d8d',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('75d14854-6c2a-4292-8055-d85864ec416f',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('4a56bd0c-8fa0-4a09-9ce1-a44d5a547f12',
#                Card(name=Muck Rats, color_identity=['B'], type=Creature — Rat, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 0}, state=None)),
#               ('129f055f-2288-457b-8aa2-8a32f6171e43',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('3773ddd4-fe68-4b38-b97d-0b1e68c7ab4d',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('cfa75940-c19e-4f46-bc54-6915d81e0a10',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('24e1e649-02e6-4e7c-82b3-8068deb824b1',
#                Card(name=Gloom Pangolin, color_identity=['B'], type=Creature — Nightmare Pangolin, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('28510fa0-695d-451f-986f-be31771c03e8',
#                Card(name=Barony Vampire, color_identity=['B'], type=Creature — Vampire, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('91774288-7bad-41ba-875e-20abf377a24c',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('fcd76917-b972-4e9e-8abe-c81ee307e5c5',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('df9d8b9d-6a6a-4e13-b058-dae9c398e9d7',
#                Card(name=Scathe Zombies, color_identity=['B'], type=Creature — Zombie, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('64a5389a-d136-400a-8e26-52be386c3fe2',
#                Card(name=Nyxborn Marauder, color_identity=['B'], type=Enchantment Creature — Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 2, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('2d160129-7897-4e2b-a8a3-010b36ff740b',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('a6e81bb1-a809-4f67-8026-2ec768746d34',
#                Card(name=Renegade Demon, color_identity=['B'], type=Creature — Demon, mana_cost={'W': 0, 'U': 0, 'B': 2, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('b21aeb93-fffb-4e25-88f4-2171db89f17f',
#                Card(name=Barony Vampire, color_identity=['B'], type=Creature — Vampire, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('c1075769-9cb7-478c-ae59-68272a30776a',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('dff6859a-369d-481e-a877-8d7adcc11cf4',
#                Card(name=Headless Horseman, color_identity=['B'], type=Creature — Zombie Knight, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('5a297800-01fd-4f0d-9427-2acc32cf1d5b',
#                Card(name=Barony Vampire, color_identity=['B'], type=Creature — Vampire, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('39bffbe2-faa3-43d1-9673-37600b188861',
#                Card(name=Undead Minotaur, color_identity=['B'], type=Creature — Zombie Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None)),
#               ('79d2cfaa-f999-40e7-92e9-5c9c6928fc76',
#                Card(name=Renegade Demon, color_identity=['B'], type=Creature — Demon, mana_cost={'W': 0, 'U': 0, 'B': 2, 'R': 0, 'G': 0, 'any': 3}, state=None)),
#               ('c31f0d49-f82e-4a15-8196-193a99910bb9',
#                Card(name=Swamp, color_identity=['B'], type=Basic Land — Swamp, mana_cost=None, state=None)),
#               ('dd4d1b2e-4043-409a-a60f-938dc2380023',
#                Card(name=Dune Beetle, color_identity=['B'], type=Creature — Insect, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 1}, state=None)),
#               ('3c5c7cce-985b-41b3-8846-7a2d91f8d999',
#                Card(name=Undead Minotaur, color_identity=['B'], type=Creature — Zombie Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 1, 'R': 0, 'G': 0, 'any': 2}, state=None))]),
#  OrderedDict([('6f931f48-4d0d-47c4-9943-f708996d4570',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('93d2484b-0260-43e8-8fcc-dc4c11daa1b8',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('69b59dae-0225-4e13-98aa-9d177789dcc2',
#                Card(name=Viashino Warrior, color_identity=['R'], type=Creature — Viashino Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('6da8e7b7-52f9-4466-a011-1772c3a9bf62',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('f53b22d4-8e2c-4102-bcce-013c4b4c8b18',
#                Card(name=Defiant Khenra, color_identity=['R'], type=Creature — Jackal Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('218e2e43-2d9c-4a76-98db-78fda1a2bbf3',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('fef33ea6-e0a2-4dbd-8591-3b14b0f2f79a',
#                Card(name=Dwarven Trader, color_identity=['R'], type=Creature — Dwarf, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 0}, state=None)),
#               ('a24b4b6b-74a5-4a86-a4b1-07aa90a13de6',
#                Card(name=Mons's Goblin Raiders, color_identity=['R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 0}, state=None)),
#               ('e87f7642-acbf-476c-bb85-eb0b6f35216b',
#                Card(name=Goblin Cavaliers, color_identity=['R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('f3af22f6-58d6-4caa-aa39-eceaf954a132',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('4e6c9913-ff12-42eb-9a16-db4c562cb238',
#                Card(name=Tor Giant, color_identity=['R'], type=Creature — Giant, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('f306293b-ac59-4c3e-a92b-4b8955aac737',
#                Card(name=Goblin Piker, color_identity=['R'], type=Creature — Goblin Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('39462cba-ab23-4762-9f4f-0f7d76c04332',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('eb4d5fbe-280b-45d5-b8dd-db0bf74045b5',
#                Card(name=Frenzied Raptor, color_identity=['R'], type=Creature — Dinosaur, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('e4360b0c-f00f-4aa0-91e1-017b699fb7ed',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('090a1c26-1746-47e4-8a29-2ff30fd48d94',
#                Card(name=Goblin Roughrider, color_identity=['R'], type=Creature — Goblin Knight, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('db8c352a-8a20-4fe9-a3bb-2ea81977171f',
#                Card(name=Hurloon Minotaur, color_identity=['R'], type=Creature — Minotaur, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 1}, state=None)),
#               ('cfd55c07-787f-4a22-8955-c52c9a7059a5',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('dbc5646d-0588-48ae-9ed1-b2e6e06b6061',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('84662174-0062-494c-8075-40ef80acc8a3',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('05b466a6-a1f1-4341-a018-86a0314266ac',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('d847d7d0-e6c8-4979-a1a8-6c1973f97efd',
#                Card(name=Independent Troops, color_identity=['R'], type=Creature — Human Soldier, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('651f989a-93da-4f8e-bc7f-edf2426ce853',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('dbbd84be-fba0-439b-bea2-e469fbdff801',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('b83481e4-95ab-4f69-953c-bda52280d6bc',
#                Card(name=Onakke Ogre, color_identity=['R'], type=Creature — Ogre Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('8bc348e2-6b9e-4106-9e4c-7816c69382cd',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('7f75da75-bf73-4900-820d-a27570bf4951',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('f553eb80-19f7-4b7d-90cc-9f00936c5f4e',
#                Card(name=Fomori Nomad, color_identity=['R'], type=Creature — Nomad Giant, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 4}, state=None)),
#               ('90e838fe-7a39-49a5-ba45-20b8dad13ebe',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('bb8a1f59-5fe7-4284-ab13-42c5e1ca7cdb',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('cac4e5d5-910c-4377-a8b4-e48f404ff62e',
#                Card(name=Goblin Piker, color_identity=['R'], type=Creature — Goblin Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('57d69462-a473-4e3a-8cce-600a9e0506a3',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('c8498a14-186a-4067-b0f3-8cf057cd20d8',
#                Card(name=Tor Giant, color_identity=['R'], type=Creature — Giant, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('97fc5f9e-648c-4f5f-9024-2f7616db781f',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('d1506a85-bc23-4a8f-9b7b-ab53872b5885',
#                Card(name=Canyon Minotaur, color_identity=['R'], type=Creature — Minotaur Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('28317711-17aa-4388-8d2c-76f0aac84032',
#                Card(name=Goblin Hero, color_identity=['R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('42ac87c2-e93c-443d-a6c1-a98b6ad0e969',
#                Card(name=Flameborn Viron, color_identity=['R'], type=Creature — Phyrexian Insect, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 2, 'G': 0, 'any': 4}, state=None)),
#               ('07040af0-7ec2-46d3-b8db-9e3aeb2cf49b',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('436e64fb-4212-48b2-9dd4-24cc39b00b42',
#                Card(name=Frenzied Raptor, color_identity=['R'], type=Creature — Dinosaur, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('9c65ec51-8b9c-4424-8aae-6d4ca7883520',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('e63c7857-7023-4a4a-9a49-2faad8c83811',
#                Card(name=Trained Orgg, color_identity=['R'], type=Creature — Orgg, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 6}, state=None)),
#               ('18ebc73d-a28c-40c0-a2a3-70c85e9ee0d0',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('3f155e26-2329-4363-971b-65ebd0ec20d6',
#                Card(name=Terror of the Fairgrounds, color_identity=['R'], type=Creature — Gremlin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('24cc7237-2abd-4bfa-8976-00832f812603',
#                Card(name=Terror of the Fairgrounds, color_identity=['R'], type=Creature — Gremlin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('ed8684d8-8c01-49d2-a252-9645fe1d32bd',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('50c2d043-7a35-4377-9682-1aece55e31a6',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('e7a4dc67-7d42-4988-81ff-6748e824cadc',
#                Card(name=Barbarian Horde, color_identity=['R'], type=Creature — Human Barbarian Soldier, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 3}, state=None)),
#               ('487e1188-50d4-4aba-8c15-6825be50b4a0',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('ac5b2cd3-d610-456a-94cc-fe4ab640270f',
#                Card(name=Falkenrath Reaver, color_identity=['R'], type=Creature — Vampire, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('dc50db58-5c45-45e9-859d-957bc3fbb322',
#                Card(name=Lathnu Sailback, color_identity=['R'], type=Creature — Lizard, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 4}, state=None)),
#               ('a3380a8c-4102-4145-8d90-1f9a09fd37a4',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('d4e37e86-133e-4db5-92c1-b083b5b5fed3',
#                Card(name=Feral Maaka, color_identity=['R'], type=Creature — Cat, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('fb4b0815-160b-41f1-a923-5c9a8690029f',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('9ea1cdca-8097-479e-bf6a-38a62cddbcd7',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('2be85882-c449-496b-b2b5-2cb9ea14d9d6',
#                Card(name=Fearless Halberdier, color_identity=['R'], type=Creature — Human Warrior, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 2}, state=None)),
#               ('448e477e-ca99-4c8f-9237-908c36046425',
#                Card(name=Goblin Bully, color_identity=['R'], type=Creature — Goblin, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None)),
#               ('c758ae8e-2201-4c2f-ab76-471d73b291d2',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('d377cbcb-914c-42f5-8270-9c10f70b02b0',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('b485ddfd-fa97-4868-9f6d-13c4f007fdbe',
#                Card(name=Mountain, color_identity=['R'], type=Basic Land — Mountain, mana_cost=None, state=None)),
#               ('6e581e72-c3d1-46df-babd-c5528c25034f',
#                Card(name=Feral Maaka, color_identity=['R'], type=Creature — Cat, mana_cost={'W': 0, 'U': 0, 'B': 0, 'R': 1, 'G': 0, 'any': 1}, state=None))])]
